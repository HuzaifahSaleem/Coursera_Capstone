# %%
import pandas as pd #library for data analysis
import numpy as np # library to handle data in a vectorized manner
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %% [markdown]
# ### Lets import the data

# %%
df = pd.read_csv('neighbourhoodswithcoordinates.csv') 
df
# Out:
#               Borough Postal Code  \
# 0     Central Toronto         M4N
# 1     Central Toronto         M4P
# 2     Central Toronto         M4R
# 3     Central Toronto         M4S
# 4     Central Toronto         M4T
# 5     Central Toronto         M4V
# 6     Central Toronto         M5N
# 7     Central Toronto         M5P
# 8     Central Toronto         M5R
# 9    Downtown Toronto         M4W
# 10   Downtown Toronto         M4X
# 11   Downtown Toronto         M4Y
# 12   Downtown Toronto         M5A
# 13   Downtown Toronto         M5B
# 14   Downtown Toronto         M5C
# 15   Downtown Toronto         M5E
# 16   Downtown Toronto         M5G
# 17   Downtown Toronto         M5H
# 18   Downtown Toronto         M5J
# 19   Downtown Toronto         M5K
# 20   Downtown Toronto         M5L
# 21   Downtown Toronto         M5S
# 22   Downtown Toronto         M5T
# 23   Downtown Toronto         M5V
# 24   Downtown Toronto         M5W
# 25   Downtown Toronto         M5X
# 26   Downtown Toronto         M6G
# 27       East Toronto         M4E
# 28       East Toronto         M4K
# 29       East Toronto         M4L
# ..                ...         ...
# 73         North York         M9M
# 74       Queen's Park         M7A
# 75        Scarborough         M1B
# 76        Scarborough         M1C
# 77        Scarborough         M1E
# 78        Scarborough         M1G
# 79        Scarborough         M1H
# 80        Scarborough         M1J
# 81        Scarborough         M1K
# 82        Scarborough         M1L
# 83        Scarborough         M1M
# 84        Scarborough         M1N
# 85        Scarborough         M1P
# 86        Scarborough         M1R
# 87        Scarborough         M1S
# 88        Scarborough         M1T
# 89        Scarborough         M1V
# 90        Scarborough         M1W
# 91        Scarborough         M1X
# 92       West Toronto         M6H
# 93       West Toronto         M6J
# 94       West Toronto         M6K
# 95       West Toronto         M6P
# 96       West Toronto         M6R
# 97       West Toronto         M6S
# 98               York         M6C
# 99               York         M6E
# 100              York         M6M
# 101              York         M6N
# 102              York         M9N
#
#                                    Neighbourhood\r\r\n   Latitude  Longitude
# 0                                        Lawrence Park  43.728020 -79.388790
# 1                               Davisville North\r\r\n  43.712751 -79.390197
# 2                             North Toronto West\r\r\n  43.715383 -79.405678
# 3                                     Davisville\r\r\n  43.704324 -79.388790
# 4                    Moore Park, Summerhill East\r\r\n  43.689574 -79.383160
# 5    Deer Park, Forest Hill SE\r\r\n, Rathnelly, So...  43.686412 -79.400049
# 6                                       Roselawn\r\r\n  43.711695 -79.416936
# 7            Forest Hill North, Forest Hill West\r\r\n  43.696948 -79.411307
# 8            The Annex, North Midtown\r\r\n, Yorkville  43.672710 -79.405678
# 9                                             Rosedale  43.679563 -79.377529
# 10                         Cabbagetown, St. James Town  43.667967 -79.367675
# 11                                Church and Wellesley  43.665860 -79.383160
# 12                           Harbourfront, Regent Park  43.654260 -79.360636
# 13                      Ryerson, Garden District\r\r\n  43.657162 -79.378937
# 14                                      St. James Town  43.651494 -79.375418
# 15                                         Berczy Park  43.644771 -79.373306
# 16                            Central Bay Street\r\r\n  43.657952 -79.387383
# 17                      Adelaide, King, Richmond\r\r\n  43.650571 -79.384568
# 18   Harbourfront East\r\r\n, Toronto Islands, Unio...  43.640816 -79.381752
# 19            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 20                Commerce Court, Victoria Hotel\r\r\n  43.648198 -79.379817
# 21                Harbord\r\r\n, University of Toronto  43.662696 -79.400049
# 22           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 23   CN Tower, Bathurst Quay\r\r\n, Island airport\...  43.628947 -79.394420
# 24               Stn A PO Boxes 25 The Esplanade\r\r\n  43.646435 -79.374846
# 25              First Canadian Place, Underground city  43.648429 -79.382280
# 26                                      Christie\r\r\n  43.669542 -79.422564
# 27                                         The Beaches  43.676357 -79.293031
# 28                  The Danforth West\r\r\n, Riverdale  43.679557 -79.352188
# 29                The Beaches West\r\r\n, India Bazaar  43.668999 -79.315572
# ..                                                 ...        ...        ...
# 73                                    Emery, Humberlea  43.724766 -79.532242
# 74                                        Queen's Park  43.662301 -79.389494
# 75                                      Rouge, Malvern  43.806686 -79.194353
# 76              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 77             Guildwood\r\r\n, Morningside, West Hill  43.763573 -79.188711
# 78                                              Woburn  43.770992 -79.216917
# 79                                           Cedarbrae  43.773136 -79.239476
# 80                                 Scarborough Village  43.744734 -79.239476
# 81   East Birchmount Park\r\r\n, Ionview, Kennedy Park  43.727929 -79.262029
# 82                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 83   Cliffcrest, Cliffside, Scarborough Village Wes...  43.716316 -79.239476
# 84                   Birch Cliff, Cliffside West\r\r\n  43.692657 -79.264848
# 85   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 86                                   Maryvale, Wexford  43.750072 -79.295849
# 87                                           Agincourt  43.794200 -79.262029
# 88   Clarks Corners\r\r\n, Sullivan\r\r\n, Tam O'Sh...  43.781638 -79.304302
# 89   Agincourt North, L'Amoreaux East\r\r\n, Millik...  43.815252 -79.284577
# 90                 L'Amoreaux West\r\r\n, Steeles West  43.799525 -79.318389
# 91                                         Upper Rouge  43.836125 -79.205636
# 92                  Dovercourt Village, Dufferin\r\r\n  43.669005 -79.442259
# 93                            Little Portugal, Trinity  43.647927 -79.419750
# 94   Brockton\r\r\n, Exhibition Place, Parkdale Vil...  43.636847 -79.428191
# 95                 High Park, The Junction South\r\r\n  43.661608 -79.464763
# 96                              Parkdale, Roncesvalles  43.648960 -79.456325
# 97                                  Runnymede, Swansea  43.651571 -79.484450
# 98                                  Humewood-Cedarvale  43.693781 -79.428191
# 99                           Caledonia-Fairbanks\r\r\n  43.689026 -79.453512
# 100  Del Ray\r\r\n, Keelesdale, Mount Dennis, Silve...  43.691116 -79.476013
# 101          The Junction North\r\r\n, Runnymede\r\r\n  43.673185 -79.487262
# 102                                             Weston  43.706876 -79.518188
#
# [103 rows x 5 columns]

# %% [markdown]
# ### Now lets look into the boroughs which contain the word "Toronto"

# %%
toronto = df[df['Borough'].str.contains('Toronto', regex=False, case=False, na=False)]
toronto.head(10)
# Out:
#             Borough Postal Code  \
# 0   Central Toronto         M4N
# 1   Central Toronto         M4P
# 2   Central Toronto         M4R
# 3   Central Toronto         M4S
# 4   Central Toronto         M4T
# 5   Central Toronto         M4V
# 6   Central Toronto         M5N
# 7   Central Toronto         M5P
# 8   Central Toronto         M5R
# 9  Downtown Toronto         M4W
#
#                                  Neighbourhood\r\r\n   Latitude  Longitude
# 0                                      Lawrence Park  43.728020 -79.388790
# 1                             Davisville North\r\r\n  43.712751 -79.390197
# 2                           North Toronto West\r\r\n  43.715383 -79.405678
# 3                                   Davisville\r\r\n  43.704324 -79.388790
# 4                  Moore Park, Summerhill East\r\r\n  43.689574 -79.383160
# 5  Deer Park, Forest Hill SE\r\r\n, Rathnelly, So...  43.686412 -79.400049
# 6                                     Roselawn\r\r\n  43.711695 -79.416936
# 7          Forest Hill North, Forest Hill West\r\r\n  43.696948 -79.411307
# 8          The Annex, North Midtown\r\r\n, Yorkville  43.672710 -79.405678
# 9                                           Rosedale  43.679563 -79.377529

# %% [markdown]
# ### Nows lets put in the foursquare credentials

# %%
CLIENT_ID = 'CRVLOBOKYSFY3MOEWLO2LJWUGEHHMRNITJY21VWYRTYPKFOR' # your Foursquare ID
CLIENT_SECRET = 'SVSKWCVMEEK0WERNY4MXSERLLVVDUXPZFOHN2IU35AQRQ0R5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CRVLOBOKYSFY3MOEWLO2LJWUGEHHMRNITJY21VWYRTYPKFOR
# CLIENT_SECRET:SVSKWCVMEEK0WERNY4MXSERLLVVDUXPZFOHN2IU35AQRQ0R5

# %% [markdown]
# ### Function to get nearby veneues in a neighbourhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto['Neighbourhood'],latitudes=toronto['Latitude'],longitudes=toronto['Longitude'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python3\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Neighbourhood\n'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-3faca17d0077> in <module>()
# ----> 1 toronto_venues = getNearbyVenues(names=toronto['Neighbourhood\n'],latitudes=toronto['Latitude'],longitudes=toronto['Longitude'])
#
# C:\Python3\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\Python3\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\Python3\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\Python3\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Python3\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Neighbourhood\n'
