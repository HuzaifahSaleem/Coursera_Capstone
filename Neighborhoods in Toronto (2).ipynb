# %%
import pandas as pd

# %% [markdown]
# ### Importing both datasets into dataframes

# %%
dataset1 = pd.read_csv('neighbourhoods.csv')
dataset1.head(4)
# Out:
#    Unnamed: 0          Borough Postcode       Neighbourhood\r\n
# 0           0  Central Toronto      M4N           Lawrence Park
# 1           1  Central Toronto      M4P    Davisville North\r\n
# 2           2  Central Toronto      M4R  North Toronto West\r\n
# 3           3  Central Toronto      M4S          Davisville\r\n

# %%
dataset2 = pd.read_csv('Geospatial_Coordinates.csv')
dataset2.head(4)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917

# %% [markdown]
# ### now to create a merged dataframe containing neighbourhoods and their coordinates

# %%
dataset1.rename(columns={'Postcode':'Postal Code'}, inplace=True)
df = pd.merge(dataset1, dataset2, on='Postal Code', how='inner')
df
# Out:
#      Unnamed: 0           Borough Postal Code  \
# 0             0   Central Toronto         M4N
# 1             1   Central Toronto         M4P
# 2             2   Central Toronto         M4R
# 3             3   Central Toronto         M4S
# 4             4   Central Toronto         M4T
# 5             5   Central Toronto         M4V
# 6             6   Central Toronto         M5N
# 7             7   Central Toronto         M5P
# 8             8   Central Toronto         M5R
# 9             9  Downtown Toronto         M4W
# 10           10  Downtown Toronto         M4X
# 11           11  Downtown Toronto         M4Y
# 12           12  Downtown Toronto         M5A
# 13           13  Downtown Toronto         M5B
# 14           14  Downtown Toronto         M5C
# 15           15  Downtown Toronto         M5E
# 16           16  Downtown Toronto         M5G
# 17           17  Downtown Toronto         M5H
# 18           18  Downtown Toronto         M5J
# ...

# %%
df.shape
# Out:
# (103, 6)

# %%
df.to_csv('neighbourhoodswithcoordinates.csv')
